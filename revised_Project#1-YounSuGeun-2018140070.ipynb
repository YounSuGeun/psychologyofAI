# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
class NN:
    def __init__(self, inputnodes, hiddennodes, outputnodes, learningrate):
        self.inodes = inputnodes
        self.hnodes = hiddennodes
        self.onodes = outputnodes
        self.wih = numpy.random.normal(0.0, pow(self.inodes, -0.5), (self.hnodes, self.inodes))
        self.who = numpy.random.normal(0.0, pow(self.hnodes, -0.5), (self.onodes, self.hnodes))
        self.lr = learningrate
        self.v_who = 0
        self.v_wih = 0
    
    def activation_function(self, x):
        return 1 / (1 + numpy.exp(-x))
    
    def train(self, inputs_list, targets_list):
        inputs = numpy.array(inputs_list, ndmin=2).T
        targets = numpy.array(targets_list, ndmin=2).T

        # Forward pass
        hidden_inputs = numpy.dot(self.wih, inputs)
        hidden_outputs = self.activation_function(hidden_inputs)
        final_inputs = numpy.dot(self.who, hidden_outputs)
        final_outputs = self.activation_function(final_inputs)

        # Compute errors
        output_errors = targets - final_outputs
        hidden_errors = numpy.dot(self.who.T, output_errors)
        
        
        momentum = 0.9

        # Update hidden-to-output weights (self.who)
        self.v_who = momentum * self.v_who + self.lr * numpy.dot((output_errors * final_outputs * (1.0 - final_outputs)), numpy.transpose(hidden_outputs))
        self.who += self.v_who

        # Update input-to-hidden weights (self.wih)
        self.v_wih = momentum * self.v_wih + self.lr * numpy.dot((hidden_errors * hidden_outputs * (1.0 - hidden_outputs)), numpy.transpose(inputs))
        self.wih += self.v_wih

    def test(self, inputs_list):
        inputs = numpy.array(inputs_list, ndmin=2).T
        hidden_inputs = numpy.dot(self.wih, inputs)
        hidden_outputs = self.activation_function(hidden_inputs)
        final_inputs = numpy.dot(self.who, hidden_outputs)
        final_outputs = self.activation_function(final_inputs)
        return final_outputs

# %%
import requests
requests.packages.urllib3.disable_warnings()
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    # Legacy Python that doesn't verify HTTPS certificates by default
    pass
else:
    # Handle target environment that doesn't support HTTPS verification
    ssl._create_default_https_context = _create_unverified_https_context

# %%
training_data_file = pd.read_csv('mnist_traindata.csv')
training_data_list = training_data_file.to_numpy()
test_data_file = pd.read_csv('mnist_exampledata1.csv')
test_data_list = test_data_file.to_numpy()

# %%
def ANN(hn, lr):
  hidden_nodes = int(hn)
  learning_rate = float(lr)
  input_nodes = 784
  output_nodes = 10
  epochs = 20
  n = NN(input_nodes,hidden_nodes,output_nodes, learning_rate)
  global pf_list
  pf_list = []
  for e in range(epochs):
    for record in training_data_list: #row 별로 반복
        inputs = (record[1:] / 255.0 * 0.99) + 0.01 # normalize input value to 0.01~1
        targets = numpy.zeros(output_nodes) + 0.01
        targets[record[0]] = 0.99 #target one-hot encoding from 0.1 to 0.99
        n.train(inputs, targets)
        
    scorecard = []
    for record in test_data_list:
      correct_label = record[0] #정답
      inputs = (record[1:] / 255.0 * 0.99) + 0.01
      outputs = n.test(inputs) #test 결과
      label = numpy.argmax(outputs) #test 결과를 자연수로 변환
      if (label == correct_label):
        scorecard.append(1) #정답이면 1, 오답이면 0 추가
      else:
        scorecard.append(0)
        
    scorecard = numpy.asarray(scorecard)
    performance =  scorecard.sum() / scorecard.size
    pf_list.append(performance)
    
    with open(f"wih_{learning_rate}_{hidden_nodes}_{e}","wb")as file:
        pickle.dump(n.wih,file)
    with open(f"who_{learning_rate}_{hidden_nodes}_{e}","wb")as file:
        pickle.dump(n.who,file)
    
  global max_performance
  global max_epoch
  max_performance = max(pf_list) #가장 높은 정확도
  max_epoch = pf_list.index(max(pf_list)) #가장 높은 정확도가 나왔을 때의 epoch: color coding
  
  return (max_performance, max_epoch)

# %%
###이 밑으로는 Hidden Nodes, Learning Rate 바꿔가면서 실험###

# %%
performance_list=[]
epoch_list=[]

for i in range(10,110,10):
    ANN(i,0.01)
    performance_list.append(max_performance)
    epoch_list.append(max_epoch)
    

plt.scatter(range(10, 110, 10), performance_list, c=epoch_list, cmap='viridis')
plt.colorbar(label='Max Epoch')
plt.xlabel('i')
plt.ylabel('Max Performance')
plt.title('Performance of ANN')
plt.show()

# %%
print("Maximum Performance:", max(performance_list))
print("Epochs:", epoch_list[performance_list.index(max(performance_list))])
print("Hidden Nodes:", range(10, 110, 10)[performance_list.index(max(performance_list))])
# Out:
# Maximum Performance: 0.9744974497449745
# Epochs: 9
# Hidden Nodes: 100

# %%
performance_list=[]
epoch_list=[]

for i in range(10,110,10):
    ANN(i,0.001)
    performance_list.append(max_performance)
    epoch_list.append(max_epoch)

plt.scatter(range(10, 110, 10), performance_list, c=epoch_list, cmap='viridis')
plt.colorbar(label='Max Epoch')
plt.xlabel('i')
plt.ylabel('Max Performance')
plt.title('Performance of ANN')
plt.show()

# %%
print("Maximum Performance:", max(performance_list))
print("Epochs:", epoch_list[performance_list.index(max(performance_list))])
print("Hidden Nodes:", range(10, 110, 10)[performance_list.index(max(performance_list))])
# Out:
# Maximum Performance: 0.9746974697469747
# Epochs: 19
# Hidden Nodes: 90

# %%
performance_list=[]
epoch_list=[]

for i in range(20,210,20):
    ANN(i,0.01)
    performance_list.append(max_performance)
    epoch_list.append(max_epoch)

max_performance = max(performance_list)
max_performance_index = performance_list.index(max_performance)
max_epoch = epoch_list[max_performance_index]

plt.scatter(range(20, 210, 20), performance_list, c=epoch_list, cmap='viridis')
plt.colorbar(label='Max Epoch')
plt.xlabel('i')
plt.ylabel('Max Performance')
plt.title('Performance of ANN')
plt.show()

# %%
print("Maximum Performance:", max(performance_list))
print("Epochs:", epoch_list[performance_list.index(max(performance_list))])
print("Hidden Nodes:", range(20, 210, 20)[performance_list.index(max(performance_list))])
# Out:
# Maximum Performance: 0.9815981598159816
# Epochs: 15
# Hidden Nodes: 200

# %%
performance_list=[]
epoch_list=[]

for i in range(20,210,20):
    ANN(i,0.003)
    performance_list.append(max_performance)
    epoch_list.append(max_epoch)

plt.scatter(range(20, 210, 20), performance_list, c=epoch_list, cmap='viridis')
plt.colorbar(label='Max Epoch')
plt.xlabel('i')
plt.ylabel('Max Performance')
plt.title('Performance of ANN')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48056\3145529508.py in <module>
#       3
#       4 for i in range(20,210,20):
# ----> 5     ANN(i,0.003)
#       6     performance_list.append(max_performance)
#       7     epoch_list.append(max_epoch)
#
# ~\AppData\Local\Temp\ipykernel_48056\15325988.py in ANN(hn, lr)
#      13         targets = numpy.zeros(output_nodes) + 0.01
#      14         targets[record[0]] = 0.99 #target one-hot encoding from 0.1 to 0.99
# ---> 15         n.train(inputs, targets)
#      16
#      17     scorecard = []
#
# ~\AppData\Local\Temp\ipykernel_48056\3070785676.py in train(self, inputs_list, targets_list)
#      18
#      19         # Forward pass
# ---> 20         hidden_inputs = numpy.dot(self.wih, inputs)
#      21         hidden_outputs = self.activation_function(hidden_inputs)
#      22         final_inputs = numpy.dot(self.who, hidden_outputs)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
plt.scatter(range(20, 190, 20), performance_list, c=epoch_list, cmap='viridis')
plt.colorbar(label='Max Epoch')
plt.xlabel('i')
plt.ylabel('Max Performance')
plt.title('Performance of ANN')
plt.show()

# %%
print("Maximum Performance:", max(performance_list))
print("Epochs:", epoch_list[performance_list.index(max(performance_list))])
print("Hidden Nodes:", range(20, 210, 20)[performance_list.index(max(performance_list))])
# Out:
# Maximum Performance: 0.9817981798179818
# Epochs: 15
# Hidden Nodes: 180

# %%
#Hidden Nodes 200
performance_list=[]
epoch_list=[]

ANN(200,0.003)

plt.plot(pf_list)

plt.xlabel("epochs")
plt.ylabel("performance")
plt.title(f"performance by learningrate({learning_rate}) & the number of hidden nodes({hidden_nodes})")
plt.show()
print("maximum performance:",max(pf_list),"the epoch:",pf_list.index(max(pf_list)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16308\1458941180.py in <module>
#       8 plt.xlabel("epochs")
#       9 plt.ylabel("performance")
# ---> 10 plt.title(f"performance by learningrate({learning_rate}) & the number of hidden nodes({hidden_nodes})")
#      11 plt.show()
#      12 print("maximum performance:",max(pf_list),"the epoch:",pf_list.index(max(pf_list)))
#
# NameError: name 'learning_rate' is not defined

# %%
print("maximum performance:",max(pf_list),"the epoch:",pf_list.index(max(pf_list)))
# Out:
# maximum performance: 0.9811981198119812 the epoch: 17

# %%
performance_list=[]
epoch_list=[]

for i in range(20,210,20):
    ANN(i,0.005)
    performance_list.append(max_performance)
    epoch_list.append(max_epoch)

max_performance = max(performance_list)
max_performance_index = performance_list.index(max_performance)
max_epoch = epoch_list[max_performance_index]

plt.scatter(range(20, 210, 20), performance_list, c=epoch_list, cmap='viridis')
plt.colorbar(label='Max Epoch')
plt.xlabel('i')
plt.ylabel('Max Performance')
plt.title('Performance of ANN')
plt.show()

# %%
print("Maximum Performance:", max(performance_list))
print("Epochs:", epoch_list[performance_list.index(max(performance_list))])
print("Hidden Nodes:", range(20, 210, 20)[performance_list.index(max(performance_list))])
# Out:
# Maximum Performance: 0.9806980698069807
# Epochs: 17
# Hidden Nodes: 160

# %%
###실험 결과 Hidden Nodes 180, Learning Rate 0.03일때 최고 성능###
###이를 이용하여 Decaying Learning Rate을 추가한 ANN 제작###

# %%
def DNN(): #Decaying ANN
  hidden_nodes = 180 #best performance based on prior experiment
  learning_rate = 0.03
  input_nodes = 784
  output_nodes = 10
  epochs = 30
  n = NN(input_nodes,hidden_nodes,output_nodes, learning_rate)
  global pf_list
  pf_list = []
  for e in range(epochs):
    for record in training_data_list: #row 별로 반복
        inputs = (record[1:] / 255.0 * 0.99) + 0.01 # normalize input value to 0.01~1
        targets = numpy.zeros(output_nodes) + 0.01
        targets[record[0]] = 0.99 #target one-hot encoding from 0.1 to 0.99
        n.train(inputs, targets)
        
    if (e + 1) % 3 == 0: # Learning Rate Decay every 3 Epoch
            n.lr *= 0.9
        
    scorecard = []
    for record in test_data_list:
      correct_label = record[0] #정답
      inputs = (record[1:] / 255.0 * 0.99) + 0.01
      outputs = n.test(inputs) #test 결과
      label = numpy.argmax(outputs) #test 결과를 자연수로 변환
      if (label == correct_label):
        scorecard.append(1) #정답이면 1, 오답이면 0 추가
      else:
        scorecard.append(0)
        
    scorecard = numpy.asarray(scorecard)
    performance =  scorecard.sum() / scorecard.size
    pf_list.append(performance)
    
    with open(f"wih_{learning_rate}_{hidden_nodes}_{e}","wb")as file:
        pickle.dump(n.wih,file)
    with open(f"who_{learning_rate}_{hidden_nodes}_{e}","wb")as file:
        pickle.dump(n.who,file)

# %%
DNN()

plt.plot(pf_list)
plt.xlabel("epochs")
plt.ylabel("performance")
plt.title("performance of DNN")
plt.show()
print("Maximum performance:",max(pf_list),"The Epoch:",pf_list.index(max(pf_list)))
# Out:
# Maximum performance: 0.9700970097009701 The Epoch: 27

# %%
#최고 성능 나온 180 Hidden Nodes, 0.03 Lr로 진행
# Load the weights for self.wih
with open("wih_0.03_180_14", "rb") as file:
    wih_weights = pickle.load(file)

# Load the weights for self.who
with open("who_0.03_180_14", "rb") as file:
    who_weights = pickle.load(file)
    
best_ann = NN(784, 180, 10, 0.03)

best_ann.wih = wih_weights
best_ann.who = who_weights

real_test_data_file = pd.read_csv('mnist_evaldata.csv')
real_test_data_list = real_test_data_file.to_numpy()

scorecard = []
for record in real_test_data_list:
    correct_label = record[0] #정답
    inputs = (record[1:] / 255.0 * 0.99) + 0.01
    outputs = best_ann.test(inputs) #test 결과
    label = numpy.argmax(outputs) #test 결과를 자연수로 변환
    if (label == correct_label):
        scorecard.append(1) #정답이면 1, 오답이면 0 추가
    else:
        scorecard.append(0)
        
scorecard = numpy.asarray(scorecard)
performance =  scorecard.sum() / scorecard.size
print(performance)
# Out:
# 0.972099302482562
